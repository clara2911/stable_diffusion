# %%
# !pip install diffusers==0.4.0 transformers scipy ftfy
# Out:
# Looking in indexes: https://pypi.org/simple, https://snappet-package-python:****@snappet.pkgs.visualstudio.com/_packaging/snappet-package-python/pypi/simple/
# ...

# %%
from diffusers import StableDiffusionPipeline
import torch

# %%
MY_TOKEN = "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" #TODO put this in a csv file

# %%
# pipe = StableDiffusionPipeline.from_pretrained("CompVis/stable-diffusion-v1-4", use_auth_token=MY_TOKEN)
pipe = StableDiffusionPipeline.from_pretrained("CompVis/stable-diffusion-v1-4", revision="fp16", torch_dtype=torch.float16, use_auth_token=MY_TOKEN)
# Out:
# ...
# Fetching 16 files:   6%|█▍                    | 1/16 [00:02<00:33,  2.27s/it]
# Downloading: 100%|███████████████████████| 4.63k/4.63k [00:00<00:00, 424kB/s]
# Fetching 16 files:  19%|████▏                 | 3/16 [00:04<00:19,  1.50s/it]
# Downloading:   0%|                                | 0.00/608M [00:00<?, ?B/s]
# Downloading:   0%|                        | 505k/608M [00:00<02:05, 4.83MB/s]
# Downloading:   0%|                       | 1.05M/608M [00:00<02:00, 5.03MB/s]
# Downloading:   0%|                       | 1.55M/608M [00:00<02:11, 4.62MB/s]
# Downloading:   0%|                       | 2.02M/608M [00:00<02:15, 4.48MB/s]
# Downloading:   0%|                       | 2.47M/608M [00:00<02:14, 4.49MB/s]
# Downloading:   0%|                       | 2.92M/608M [00:00<03:10, 3.17MB/s]
# Downloading:   1%|▏                      | 3.88M/608M [00:00<02:07, 4.75MB/s]
# Downloading:   1%|▏                      | 4.43M/608M [00:00<02:04, 4.84MB/s]
# ...

# %%
prompt = "a painting of a goat swimming in the sea"
output = pipe(prompt)
# output = pipe(prompt, num_inference_steps=5, height=512, width=512)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [23], in <cell line: 2>()
#       1 prompt = "a painting of a goat swimming in the sea"
# ----> 2 output = pipe(prompt)
#
# File ~\anaconda3\envs\stable_diffusion\lib\site-packages\torch\autograd\grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File ~\anaconda3\envs\stable_diffusion\lib\site-packages\diffusers\pipelines\stable_diffusion\pipeline_stable_diffusion.py:219, in StableDiffusionPipeline.__call__(self, prompt, height, width, num_inference_steps, guidance_scale, negative_prompt, num_images_per_prompt, eta, generator, latents, output_type, return_dict, callback, callback_steps, **kwargs)
# ...

# %%
output
# Out:
# StableDiffusionPipelineOutput(images=[<PIL.Image.Image image mode=RGB size=512x512 at 0x2EEB8B25840>], nsfw_content_detected=[True])

# %%
image = output["sample"][0]

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>
